# %% [markdown]
# ## Importing the Libraries

# %%
# !pip install contractions
# !pip install nltk


# Standard library imports
import string
import re

import contractions
import nltk
import pandas as pd
import matplotlib.pyplot as plt
from numpy import *
import seaborn as sns
from gensim.models import Word2Vec
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import TweetTokenizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV, train_test_split
from wordcloud import WordCloud, STOPWORDS


# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# Requirement already satisfied: contractions in /usr/local/lib/python3.10/dist-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.10/dist-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.10/dist-packages (from textsearch>=0.0.21->contractions) (0.3.2)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.10/dist-packages (from textsearch>=0.0.21->contractions) (2.0.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ## Read in the Data

# %%
unclean_df = pd.read_csv("stock_data_text.csv")

# %% [markdown]
# ## Analysing the Data

# %%
unclean_df.head(10)
# Out:
#                                                 Text  Sentiment
# 0  Kickers on my watchlist XIDE TIT SOQ PNK CPW B...          1
# 1  user: AAP MOVIE. 55% return for the FEA/GEED i...          1
# 2  user I'd be afraid to short AMZN - they are lo...          1
# 3                                  MNTA Over 12.00            1
# 4                                   OI  Over 21.37            1
# 5                                  PGNX  Over 3.04            1
# 6  AAP - user if so then the current downtrend wi...         -1
# 7  Monday's relative weakness. NYX WIN TIE TAP IC...         -1
# 8  GOOG - ower trend line channel test & volume s...          1
# 9             AAP will watch tomorrow for ONG entry.          1

# %%
unclean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5791 entries, 0 to 5790
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Text       5791 non-null   object
#  1   Sentiment  5791 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 90.6+ KB

# %%
unclean_df.describe()
# Out:
#          Sentiment
# count  5791.000000
# mean      0.272664
# std       0.962192
# min      -1.000000
# 25%      -1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Check for missing values

# %%
unclean_df.isna().sum().to_frame(name='Number of missing values')
# Out:
#            Number of missing values
# Text                              0
# Sentiment                         0

# %% [markdown]
# Check for and remove duplicate rows

# %%
before =  unclean_df.shape[0]
unclean_df.drop_duplicates(inplace=True)
after = unclean_df.shape[0]

print("No. of rows removed :", before - after)
# Out:
# No. of rows removed : 0

# %% [markdown]
# Remove HTML Syntaxes

# %%
def remove_html(data):
    html_tag=re.compile(r'<.*?>')
    data=html_tag.sub(r'',data)
    return data

# %%
unclean_df['Cleaned_Text'] = unclean_df['Text'].apply(lambda z: remove_html(z))

# %% [markdown]
# Remove URL Data

# %%
def remove_url(data):
    url_clean= re.compile(r"https://\S+|www\.\S+")
    data=url_clean.sub(r'',data)
    return data

# %%
unclean_df['Cleaned_Text'] = unclean_df['Text'].apply(lambda z: remove_url(z))

# %% [markdown]
# Remove Emojis

# %%
def remove_emoji(data):
    emoji_clean= re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    data=emoji_clean.sub(r'',data)
    url_clean= re.compile(r"https://\S+|www\.\S+")
    data=url_clean.sub(r'',data)
    return data

# %%
unclean_df['Cleaned_Text'] = unclean_df['Text'].apply(lambda z: remove_emoji(z))

# %% [markdown]
# Lower Case

# %%
ticker_df = pd.read_csv('ticker_list1.csv')
ticker_df = ticker_df['Symbol']
ticker_df.head()
# Out:
# 0        A
# 1       AA
# 2     AACG
# 3     AACI
# 4    AACIU
# Name: Symbol, dtype: object

# %%
ticker_df2 = pd.read_csv('ticker_list2.csv')
ticker_df2 = ticker_df2['Symbol']
ticker_df2.head()
# Out:
# 0        A
# 1       AA
# 2     AACG
# 3     AACI
# 4    AACIW
# Name: Symbol, dtype: object

# %%
#Merge 2 series and convert it to a list
ticker_list1 = ticker_df.tolist()
ticker_list2 = ticker_df2.tolist()
all_tickers = list(set(ticker_list1 + ticker_list2))

# %%
unclean_df.head()
# Out:
#                                                 Text  Sentiment  \
# 0  Kickers on my watchlist XIDE TIT SOQ PNK CPW B...          1
# 1  user: AAP MOVIE. 55% return for the FEA/GEED i...          1
# 2  user I'd be afraid to short AMZN - they are lo...          1
# 3                                  MNTA Over 12.00            1
# 4                                   OI  Over 21.37            1
#
#                                         Cleaned_Text
# 0  Kickers on my watchlist XIDE TIT SOQ PNK CPW B...
# 1  user: AAP MOVIE. 55% return for the FEA/GEED i...
# 2  user I'd be afraid to short AMZN - they are lo...
# 3                                  MNTA Over 12.00
# 4                                   OI  Over 21.37

# %%
def lowercase(text):
  word_list = str(text).split(' ')
  return ' '.join([word.lower() if word not in all_tickers else word for word in word_list])

unclean_df['Cleaned_Text'] = unclean_df['Cleaned_Text'].apply(lowercase)

# %%
unclean_df.head(20)
# Out:
#                                                  Text  Sentiment  \
# 0   Kickers on my watchlist XIDE TIT SOQ PNK CPW B...          1
# 1   user: AAP MOVIE. 55% return for the FEA/GEED i...          1
# 2   user I'd be afraid to short AMZN - they are lo...          1
# 3                                   MNTA Over 12.00            1
# 4                                    OI  Over 21.37            1
# 5                                   PGNX  Over 3.04            1
# 6   AAP - user if so then the current downtrend wi...         -1
# 7   Monday's relative weakness. NYX WIN TIE TAP IC...         -1
# 8   GOOG - ower trend line channel test & volume s...          1
# 9              AAP will watch tomorrow for ONG entry.          1
# 10  i'm assuming FCX opens tomorrow above the 34.2...          1
# 11  It really worries me how everyone expects the ...          1
# 12  AAP GAMCO's arry Haverty : Apple Is Extremely ...          1
# 13  user Maykiljil posted that.  I agree that MSFT...          1
# 14  Momentum is coming back to ETFC Broke MA200 re...          1
# 15  HA Hitting 35.65 means resume targeting 42 lev...          1
# 16  user gameplan shot for today but I liked  on t...          1
# 17  with FCX gapping well above ideal entry lookin...          1
# 18  user great list again, particularly like FISV ...          1
# 19                           ATHX upper trend line             1
#
#                                          Cleaned_Text
# 0   kickers on my watchlist xide tit soq pnk cpw b...
# 1   user: AAP movie. 55% return for the fea/geed i...
# 2   user i'd be afraid to short AMZN - they are lo...
# 3                                   mnta over 12.00
# 4                                    OI  over 21.37
# 5                                   pgnx  over 3.04
# 6   AAP - user if so then the current downtrend wi...
# 7   monday's relative weakness. nyx win tie TAP IC...
# 8   GOOG - ower trend line channel test & volume s...
# 9              AAP will watch tomorrow for ong entry.
# 10  i'm assuming FCX opens tomorrow above the 34.2...
# 11  it really worries me how everyone expects the ...
# 12  AAP gamco's arry haverty : apple is extremely ...
# 13  user maykiljil posted that.  i agree that MSFT...
# 14  momentum is coming back to etfc broke ma200 re...
# 15  HA hitting 35.65 means resume targeting 42 lev...
# 16  user gameplan shot for today but i liked  on t...
# 17  with FCX gapping well above ideal entry lookin...
# 18  user great list again, particularly like fisv ...
# 19                           athx upper trend line

# %% [markdown]
# Remove Contractions

# %%
unclean_df['Cleaned_Text'] = unclean_df['Cleaned_Text'].apply(contractions.fix)

# %%
unclean_df.head()
# Out:
#                                                 Text  Sentiment  \
# 0  Kickers on my watchlist XIDE TIT SOQ PNK CPW B...          1
# 1  user: AAP MOVIE. 55% return for the FEA/GEED i...          1
# 2  user I'd be afraid to short AMZN - they are lo...          1
# 3                                  MNTA Over 12.00            1
# 4                                   OI  Over 21.37            1
#
#                                         Cleaned_Text
# 0  kickers on my watchlist xide tit soq pnk cpw b...
# 1  user: AAP movie. 55% return for the fea/geed i...
# 2  user i would be afraid to short AMZN - they ar...
# 3                                  mnta over 12.00
# 4                                   OI  over 21.37

# %% [markdown]
# Remove all punctuations

# %%
def remove_punctuation(text):
  return "".join([char for char in text if char not in string.punctuation])


unclean_df['Cleaned_Text'] = unclean_df['Cleaned_Text'].apply(remove_punctuation)

# %%
unclean_df.head()
# Out:
#                                                 Text  Sentiment  \
# 0  Kickers on my watchlist XIDE TIT SOQ PNK CPW B...          1
# 1  user: AAP MOVIE. 55% return for the FEA/GEED i...          1
# 2  user I'd be afraid to short AMZN - they are lo...          1
# 3                                  MNTA Over 12.00            1
# 4                                   OI  Over 21.37            1
#
#                                         Cleaned_Text
# 0  kickers on my watchlist xide tit soq pnk cpw b...
# 1  user AAP movie 55 return for the feageed indic...
# 2  user i would be afraid to short AMZN  they are...
# 3                                   mnta over 1200
# 4                                    OI  over 2137

# %% [markdown]
# Data has been cleaned, now we make a copy of it in a variable cleaned dataframe

# %%
cleaned_df = unclean_df

# %% [markdown]
# Tokenisation

# %%
tokenizer = TweetTokenizer()
cleaned_df['Cleaned_Text'] = cleaned_df['Cleaned_Text'].apply(tokenizer.tokenize)

# %% [markdown]
# Remove Stopwords

# %%
stop_words = set(stopwords.words('english'))

# %%
#Keep these words in the text as they could correlate to sentiment
keep_in_tokens = ["no","not", "on", "off", "too", "out", "over", "under"]

for word in keep_in_tokens:
    stop_words.remove(word)
def filter_tokens(tokens):
    return [token for token in tokens if token not in stop_words]
cleaned_df["Cleaned_Text"] = cleaned_df["Cleaned_Text"].apply(filter_tokens)

# %% [markdown]
# Lemmatisation

# %%
lemmatizer = WordNetLemmatizer()
def lemmatize_tokens(filtered_tokens):
  return ' '.join([lemmatizer.lemmatize(token) for token in filtered_tokens])

cleaned_df['Cleaned_Text'] = cleaned_df['Cleaned_Text'].apply(lemmatize_tokens)

# %% [markdown]
# ### Comparing unprocessed vs processed text

# %%
cleaned_df.head(10)
# Out:
#                                                 Text  Sentiment  \
# 0  Kickers on my watchlist XIDE TIT SOQ PNK CPW B...          1
# 1  user: AAP MOVIE. 55% return for the FEA/GEED i...          1
# 2  user I'd be afraid to short AMZN - they are lo...          1
# 3                                  MNTA Over 12.00            1
# 4                                   OI  Over 21.37            1
# 5                                  PGNX  Over 3.04            1
# 6  AAP - user if so then the current downtrend wi...         -1
# 7  Monday's relative weakness. NYX WIN TIE TAP IC...         -1
# 8  GOOG - ower trend line channel test & volume s...          1
# 9             AAP will watch tomorrow for ONG entry.          1
#
#                                         Cleaned_Text
# 0  kicker on watchlist xide tit soq pnk cpw bpz a...
# 1  user AAP movie 55 return feageed indicator 15 ...
# 2  user would afraid short AMZN looking like near...
# 3                                     mnta over 1200
# 4                                       OI over 2137
# 5                                      pgnx over 304
# 6  AAP user current downtrend break otherwise sho...
# 7  monday relative weakness nyx win tie TAP ICE i...
# 8   GOOG ower trend line channel test volume support
# 9                       AAP watch tomorrow ong entry

# %%
#Re-setting the cleaned_df to only a column with the cleaned text
temp_df = cleaned_df[['Cleaned_Text', 'Sentiment']].copy()
temp_df.rename(columns = {'Cleaned_Text': 'Text'}, inplace=True)
temp_df.head()
# Out:
#                                                 Text  Sentiment
# 0  kicker on watchlist xide tit soq pnk cpw bpz a...          1
# 1  user AAP movie 55 return feageed indicator 15 ...          1
# 2  user would afraid short AMZN looking like near...          1
# 3                                     mnta over 1200          1
# 4                                       OI over 2137          1

# %%
cleaned_df = temp_df

# %% [markdown]
# ## Word Cloud

# %%
def generate_wcloud(text):
    stopwords = set(STOPWORDS)

    wordcloud = WordCloud(stopwords=stopwords, background_color='white')
    wordcloud.generate(text)

    plt.figure(figsize=(15,7))
    plt.axis('off')
    plt.imshow(wordcloud, interpolation='bilinear')
    return plt.show()

# %% [markdown]
# Semantic 1 word cloud

# %%
pos = cleaned_df.loc[cleaned_df['Sentiment'] == 1].Text
text = " ".join(review for review in pos.astype(str))

generate_wcloud(text)

# %% [markdown]
# Semantic -1 word cloud

# %%
pos = cleaned_df.loc[cleaned_df['Sentiment'] == -1].Text
text = " ".join(review for review in pos.astype(str))

generate_wcloud(text)

# %% [markdown]
# ## Train Test Split

# %% [markdown]
# Train data: 80%
# Test data: 20%

# %%
X = cleaned_df['Text']
y = cleaned_df['Sentiment']

#Generate Train Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape, X_test.shape
# Out:
# ((4632,), (1159,))

# %%
y_train.shape, y_test.shape
# Out:
# ((4632,), (1159,))

# %% [markdown]
# ## Vectorisation

# %% [markdown]
# Bag of Words Vectorizer

# %%
# Create a bag-of-words representation of the data
bow_vectorizer = CountVectorizer()
bow_vectorizer.fit(X_train)

# Transform
bow_X_train = bow_vectorizer.transform(X_train)
bow_X_test = bow_vectorizer.transform(X_test)

# %% [markdown]
# TF_IDF Vectorizer

# %%
# Create a term frequency representation of the data
tfidf_vectorizer = TfidfVectorizer()
tfidf_vectorizer.fit(X_train)

# Transform
tfidf_X_train = tfidf_vectorizer.transform(X_train)
tfidf_X_test = tfidf_vectorizer.transform(X_test)

# %% [markdown]
# ## Testing out different Models

# %%
from sklearn.metrics import accuracy_score

#Create standardised function to train and evaluate a particular model
def train_and_eval(model, trainX, trainY, testX, testY):

    # training the model
    fitted_model = model.fit(trainX, trainY)

    # getting predictions
    y_preds_train = fitted_model.predict(trainX)
    y_preds_test = fitted_model.predict(testX)

    # evaluating the model
    print()
    print(model)
    print(f"Train accuracy score : {accuracy_score(y_train, y_preds_train)}")
    print(f"Test accuracy score : {accuracy_score(y_test, y_preds_test)}")
    print('\n',40*'-')

# %% [markdown]
# Logistic Regression with BoW Vectorizer

# %%
C = [0.001, 0.01, 0.1, 1, 10]

for c in C:
    # Define model
    log_model = LogisticRegression(C=c, max_iter=500)

    # Train and evaluate model
    train_and_eval(model=log_model,
                   trainX=bow_X_train,
                   trainY=y_train,
                   testX=bow_X_test,
                   testY=y_test)
# Out:
# LogisticRegression(C=0.001, max_iter=500)
# Train accuracy score : 0.6414075993091537
# Test accuracy score : 0.6160483175150993
#
#  ----------------------------------------
#
# LogisticRegression(C=0.01, max_iter=500)
# Train accuracy score : 0.6958117443868739
# Test accuracy score : 0.6738567730802416
#
#  ----------------------------------------
#
# LogisticRegression(C=0.1, max_iter=500)
# Train accuracy score : 0.8376511226252159
# Test accuracy score : 0.7523727351164797
#
#  ----------------------------------------
#
# LogisticRegression(C=1, max_iter=500)
# Train accuracy score : 0.9667530224525043
# Test accuracy score : 0.7748058671268335
#
#  ----------------------------------------
#
# LogisticRegression(C=10, max_iter=500)
# Train accuracy score : 0.9978411053540587
# Test accuracy score : 0.7644521138912856
#
#  ----------------------------------------

# %% [markdown]
# Naive Bayes Classifier with BoW Vectorizer

# %%
alphas = [0, 0.2, 0.6, 0.8, 1]

for a  in alphas:
    # Define model
    nb_model = MultinomialNB(alpha=a)

    # Train and evaluate model
    train_and_eval(model=nb_model,
                   trainX=bow_X_train,
                   trainY=y_train,
                   testX=bow_X_test,
                   testY=y_test)
# Out:
# MultinomialNB(alpha=0)
# Train accuracy score : 0.9624352331606217
# Test accuracy score : 0.730802415875755
#
#  ----------------------------------------
#
# MultinomialNB(alpha=0.2)
# Train accuracy score : 0.9505613126079447
# Test accuracy score : 0.7644521138912856
#
#  ----------------------------------------
#
# MultinomialNB(alpha=0.6)
# Train accuracy score : 0.9317789291882557
# Test accuracy score : 0.7748058671268335
#
#  ----------------------------------------
#
# MultinomialNB(alpha=0.8)
# Train accuracy score : 0.9233592400690847
# Test accuracy score : 0.7799827437446074
#
#  ----------------------------------------
#
# MultinomialNB(alpha=1)
# Train accuracy score : 0.9158031088082902
# Test accuracy score : 0.7756686798964625
#
#  ----------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/naive_bayes.py:629: FutureWarning: The default value for `force_alpha` will change to `True` in 1.4. To suppress this warning, manually set the value of `force_alpha`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/naive_bayes.py:635: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10. Use `force_alpha=True` to keep alpha unchanged.
#   warnings.warn(

# %% [markdown]
# Random Forest Classifier with BoW Vectorizer

# %%
trees = [50,100,150,200]

for t in trees:
  RandFor = RandomForestClassifier(n_estimators = t)
  train_and_eval(model=RandFor,
                   trainX=bow_X_train,
                   trainY=y_train,
                   testX=bow_X_test,
                   testY=y_test)
# Out:
# RandomForestClassifier(n_estimators=50)
# Train accuracy score : 0.9993523316062176
# Test accuracy score : 0.7834339948231234
#
#  ----------------------------------------
#
# RandomForestClassifier()
# Train accuracy score : 0.9995682210708118
# Test accuracy score : 0.7851596203623814
#
#  ----------------------------------------
#
# RandomForestClassifier(n_estimators=150)
# Train accuracy score : 0.9995682210708118
# Test accuracy score : 0.7911993097497843
#
#  ----------------------------------------
#
# RandomForestClassifier(n_estimators=200)
# Train accuracy score : 0.9995682210708118
# Test accuracy score : 0.7868852459016393
#
#  ----------------------------------------

# %% [markdown]
# Logistic Regression with TFIDF Vectorizer

# %%
C = [0.001, 0.01, 0.1, 1, 10,]

for c in C:
    # Define model
    log_model = LogisticRegression(C=c, max_iter=500)

    # Train and evaluate model
    train_and_eval(model=log_model,
                   trainX=tfidf_X_train,
                   trainY=y_train,
                   testX=tfidf_X_test,
                   testY=y_test)
# Out:
# LogisticRegression(C=0.001, max_iter=500)
# Train accuracy score : 0.6414075993091537
# Test accuracy score : 0.6160483175150993
#
#  ----------------------------------------
#
# LogisticRegression(C=0.01, max_iter=500)
# Train accuracy score : 0.6414075993091537
# Test accuracy score : 0.6160483175150993
#
#  ----------------------------------------
#
# LogisticRegression(C=0.1, max_iter=500)
# Train accuracy score : 0.6705526770293609
# Test accuracy score : 0.6436583261432269
#
#  ----------------------------------------
#
# LogisticRegression(C=1, max_iter=500)
# Train accuracy score : 0.8676597582037997
# Test accuracy score : 0.7653149266609146
#
#  ----------------------------------------
#
# LogisticRegression(C=10, max_iter=500)
# Train accuracy score : 0.9883419689119171
# Test accuracy score : 0.7748058671268335
#
#  ----------------------------------------

# %% [markdown]
# Naive Bayes Classifier with TFIDF Vectorizer

# %%
alphas = [0, 0.2, 0.6, 0.8, 1]

for a  in alphas:
    # Define model
    nb_model = MultinomialNB(alpha=a)

    # Train and evaluate model
    train_and_eval(model=nb_model,
                   trainX=tfidf_X_train,
                   trainY=y_train,
                   testX=tfidf_X_test,
                   testY=y_test)
# Out:
# MultinomialNB(alpha=0)
# Train accuracy score : 0.9676165803108808
# Test accuracy score : 0.727351164797239
#
#  ----------------------------------------
#
# MultinomialNB(alpha=0.2)
# Train accuracy score : 0.9425734024179621
# Test accuracy score : 0.7558239861949957
#
#  ----------------------------------------
#
# MultinomialNB(alpha=0.6)
# Train accuracy score : 0.8909758203799655
# Test accuracy score : 0.734253666954271
#
#  ----------------------------------------
#
# MultinomialNB(alpha=0.8)
# Train accuracy score : 0.8672279792746114
# Test accuracy score : 0.72648835202761
#
#  ----------------------------------------
#
# MultinomialNB(alpha=1)
# Train accuracy score : 0.844559585492228
# Test accuracy score : 0.7161345987920621
#
#  ----------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/naive_bayes.py:629: FutureWarning: The default value for `force_alpha` will change to `True` in 1.4. To suppress this warning, manually set the value of `force_alpha`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/naive_bayes.py:635: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10. Use `force_alpha=True` to keep alpha unchanged.
#   warnings.warn(

# %% [markdown]
# Random Forest Classifier with TFIDF Vectorizer

# %%
trees = [50,100,150,200]

for t in trees:
  RandFor = RandomForestClassifier(n_estimators = t)
  train_and_eval(model=RandFor,
                   trainX=tfidf_X_train,
                   trainY=y_train,
                   testX=tfidf_X_test,
                   testY=y_test)
# Out:
# RandomForestClassifier(n_estimators=50)
# Train accuracy score : 0.9991364421416234
# Test accuracy score : 0.7756686798964625
#
#  ----------------------------------------
#
# RandomForestClassifier()
# Train accuracy score : 0.9993523316062176
# Test accuracy score : 0.7825711820534944
#
#  ----------------------------------------
#
# RandomForestClassifier(n_estimators=150)
# Train accuracy score : 0.9995682210708118
# Test accuracy score : 0.7799827437446074
#
#  ----------------------------------------
#
# RandomForestClassifier(n_estimators=200)
# Train accuracy score : 0.9995682210708118
# Test accuracy score : 0.7825711820534944
#
#  ----------------------------------------

# %% [markdown]
# ## Best Model

# %% [markdown]
# Comparing the results above, Random Forest Classifier with BoW data performs the best on test data

# %%
RandFor = RandomForestClassifier(n_estimators = 150)
train_and_eval(model=RandFor,
                  trainX=bow_X_train,
                  trainY=y_train,
                  testX=bow_X_test,
                  testY=y_test)
# Out:
# RandomForestClassifier(n_estimators=150)
# Train accuracy score : 0.9995682210708118
# Test accuracy score : 0.7929249352890423
#
#  ----------------------------------------

# %% [markdown]
# The Random Forest Classifier is the best fit, with a test accuracy score of 79% when setting the optimal number of trees = 150.
